# %% [markdown]
# <a href="https://colab.research.google.com/github/areekakhalil/Week1_MiniProject_GDGOC_ML-DL-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://raw.githubusercontent.com/codebasics/py/master/ML/18_PCA/Exercise/heart.csv"
import pandas as pd
df = pd.read_csv("heart.csv")
df.head()
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")
# Out:
# --2026-03-13 01:44:52--  https://raw.githubusercontent.com/codebasics/py/master/ML/18_PCA/Exercise/heart.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35921 (35K) [text/plain]
# Saving to: ‘heart.csv.5’
#
# heart.csv.5         100%[===================>]  35.08K  --.-KB/s    in 0.004s
#
# 2026-03-13 01:44:52 (8.19 MB/s) - ‘heart.csv.5’ saved [35921/35921]

# %%
df = pd.read_csv("heart.csv")
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (918, 12)
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
z_scores = np.abs(stats.zscore(df[numeric_cols]))
mask = (z_scores < 3).all(axis=1)
df = df[mask].reset_index(drop=True)
print(f"Rows after outlier removal: {len(df)}")
# Out:
# Rows after outlier removal: 899

# %%
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
le = LabelEncoder()
for col in cat_cols:
    if df[col].nunique() == 2:
        df[col] = le.fit_transform(df[col])

ohe_cols = [col for col in cat_cols if df[col].dtype == "object"]
df = pd.get_dummies(df, columns=ohe_cols, drop_first=True)
df.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    1        140          289          0    172               0
# 1   49    0        160          180          0    156               0
# 2   37    1        130          283          0     98               0
# 3   48    0        138          214          0    108               1
# 4   54    1        150          195          0    122               0
#
#    Oldpeak  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0      0.0             0               True              False
# 1      1.0             1              False               True
# 2      0.0             0               True              False
# 3      1.5             1              False              False
# 4      0.0             0              False               True
#
#    ChestPainType_TA  RestingECG_Normal  RestingECG_ST  ST_Slope_Flat  \
# 0             False               True          False          False
# ...

# %%
X = df.drop(columns=["HeartDisease"])
y = df["HeartDisease"]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)
print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Train: (719, 15), Test: (180, 15)

# %%
models = {
    "SVM":                 SVC(kernel="rbf", random_state=42),
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest":       RandomForestClassifier(n_estimators=100, random_state=42),
}
results_no_pca = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    acc = accuracy_score(y_test, model.predict(X_test))
    results_no_pca[name] = acc
    print(f"{name}: {acc*100:.2f}%")
# Out:
# SVM: 89.44%
# Logistic Regression: 87.22%
# Random Forest: 86.67%

# %%
pca = PCA(n_components=0.95, random_state=42)  # keep 95% variance
X_train_pca = pca.fit_transform(X_train)
X_test_pca  = pca.transform(X_test)
print(f"Reduced to {pca.n_components_} components")

for name, model in models.items():
    model.fit(X_train_pca, y_train)
    acc = accuracy_score(y_test, model.predict(X_test_pca))
    diff = acc - results_no_pca[name]
    print(f"{name}: {acc*100:.2f}%  ({'▲' if diff>=0 else '▼'}{abs(diff)*100:.2f}%)")
# Out:
# Reduced to 13 components
# SVM: 88.89%  (▼0.56%)
# Logistic Regression: 87.22%  (▲0.00%)
# Random Forest: 88.33%  (▲1.67%)
